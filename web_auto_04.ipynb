# %%
import requests as rq
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# %%
url = "https://news.naver.com"

res = rq.get(url)

soup = bs(res.text, "html.parser")

findP = soup.select("p")
for i in findP:
    print(">>", i.get_text())
# Out:
# >> 캄보디아에서 숨진 채 발견된 여성 인터넷 방송 진행자 BJ아영(본명 변아영·33)을 살해한 혐의를 받고 있는 중국인 부부에게 ‘고문을 동반한 살해’ 혐의가 적용됐다. 중국인 부부는 변씨가 치료 중 갑자기 발작을 일으
# >> 최근 전국 곳곳에서 '먹거리 바가지요금 문제' 논란이 이어지는 가운데, 같은 문제가 수원 한 축제에서도 발생했습니다. 어제(14일) 한 온라인 커뮤니티에는 '주말에 열렸던 수원 축제 후기'라는 제목의 글이 올라왔습니
# >> In this series, The Korea Herald sits down with members of the 21st National Assembly to discuss top political events an
# >> KBS가 TV수신료 분리징수를 추진하는 방송통신위원회에 강한 유감을 표명하며 법적 대응을 시사했다. KBS는 14일 “수신료 분리징수는 공영방송의 존립마저 위협한다”며 “충분한 고민과 사회적 논의 없이 일방적으로 수
# >> 사실을 말했다는 이유로 형사처벌을 해서는 안 된다는 주장은 오래되었다. 형법 제307조 제1항에 대한 비판이다. 조문을 그대로 옮겨본다. '공연히 사실을 적시하여 사람의 명예를 훼손한 자는 2년 이하의 징역이나 금고
# >> 오늘(15일) 오전 8시 20분쯤 수도권 지하철 1호선 신도림역에서 하차하던 여성 승객이 인파에 밀려 넘어졌습니다. 이 승객은 용산행 급행 열차에서 내리던 중 넘어져 어지럼증을 호소했고, 현장에 출동한 119구급대의
# >> 국조실 1차장 "기준치 초과 오염수 그대로 방출 아냐"... 매일 '후쿠시마 오염수' 브리핑 진행 ▲ 박구연 국무조정실 국무1차장(사진 가장 왼쪽)이 15일 정부서울청사 별관에서 후쿠시마 원전 오염수 방류 관련 브리
# >> 구제역 발생으로 인해 충북 청주와 증평 지역 축산농가에 내려졌던 이동제한조치가 완전히 해제됐고 구제역 위기 경보도 하향 조정됐다. 농림축산식품부는 지난달 10일부터 18일까지 충북 청주와 증평 지역 소‧염
# >> With the relations between China and South Korea hitting new lows almost on a daily basis, consumers in each country are
# >> 돈스파이크(45·김민수)가 마약류 매수·투약·소지 혐의로 기소돼 항소심에서 징역 2년을 선고받고 법정 구속됐다. 15일 서울고법 형사3부(부장판사 이창형)는 특정범죄 가중처벌 등에 관한 법률 위반(향정) 등 혐의로
# >> 경남 거창은 산들의 고향이다. 백두대간과 가야기맥, 진양기맥, 양각지맥 등의 수많은 산들이 병풍처럼 둘러싼 분지에 터를 닦고 있다. 군내에 걸친 산만 해도 50여 개에 이른다. 또한 덕유산, 가야산, 지리산이 그 외
# >> 인천 소래포구 상인들이 바가지 등을 척결하겠다며 엎드려 사과했습니다. 어제(14일) 인천 남동구 소래포구 전통어시장에서는 호객 행위, 섞어 팔기, 물치기, 바가지 등 그동안 시장에서 공공연히 이뤄졌던 악습들을 척결하
# >> 연세대학교 학생이 학교 화장실에서 다른 학생을 불법 촬영한 혐의로 경찰에 체포됐습니다. 서대문경찰서는 어제(14일) 낮 12시쯤 "남자화장실에서 불법 촬영 피해를 당했다"는 신고를 받고 출동해 연세대 재학생 A 씨를
# >> MBC "국방부, 개발 중인 무기 동원해라"…국방부 "강제성은 없다" 해명 국군의 날 시가행진을 10년 만에 부활하는 것을 두고 논란이 있는 가운데, 정부가 방산업체에 개발 중인 무기를 가져오라고 요구한 것으로 드러
# >> 경찰이 황보승희 국민의힘 의원(부산 중·영도)의 불법 정치자금 의혹 수사를 벌이는 가운데, 돈을 건넨 사람 등이 기록된 명부를 입수했다. 아울러 황보 의원과 동거 중인 사업가가 의원실 관용차와 보좌진, 사무실 경비
# >> 일본의 후쿠시마 오염수 방류가 점점 다가오고 있는 분위기입니다. 벌써부터 소금이나 건어물 등을 미리 사둔다는 이야기도 나오고 있습니다. 이런 가운데 제주와 충주 등 전국 곳곳의 지방의회에서 후쿠시마 오염수 방류 반대
# >> 코스맥스는 2년여의 연구 끝에 영지버섯 추출물을 활용한 천연 탈모 완화 기능성 소재를 개발했다고 15일 밝혔다. 맞춤형 화장품 플랫폼 3WAAU(쓰리와우)의 샴푸 및 트리트먼트 제품에 해당 소재를 적용하고, 연내 중
# >> 소설가 오정희가 서울국제도서전 홍보대사로 위촉된 것에 항의하던 예술인들이 도서전 개막식에서 강제로 퇴거당했다. 오 소설가는 박근혜 정부 당시 문화예술계 ‘블랙리스트’ 실행을 주도한 한국문화예술위원회 위원이었다. 국내
# >> 동급생을 7시간 동안 무자비하게 폭행하고 이를 영상으로 촬영해 SNS에 공유한 이른바 ‘태안판 더글로리’ 사건의 가해 중학생들이 결국 재판에 넘겨졌습니다. 검찰은 이들이 미성년자 신분이지만 범행의 정도와 경위 등을
# >> '연봉 100억원의 일타강사'로 알려진 수학 강사 정승제가 인스타그램 등 SNS에 호캉스(호텔에서 즐기는 휴가)나 오마카세(특선 요리)를 자랑하는 이른바 '허세' 문화때문에 대한민국의 저출산 현상이 심화한 것이라고
# >> 첫 공판서 공소사실 대부분 부인 200억 원대 횡령·배임과 계열사 부당 지원 등 혐의를 받는 조현범 한국타이어 회장이 첫 공판에서 혐의 대부분을 부인했다. 서울중앙지법 형사합의23부(조병구 부장판사)는 14일 특정경
# >> 아인슈타인의 상대성이론 이야기 중 널리 퍼진 것이 ‘쌍둥이 역설’입니다. 쌍둥이 중 한 명이 빛의 속도에 가깝게 빠른 우주선으로 여행하고 몇 년 뒤 돌아오면, 시간 지연 현상에 따라 지구에 사는 다른 쌍둥이와 다른
# >> 일반 콜라와 사이다 대신 제로 콜라, 제로 사이다를 찾는 사람이 많아졌다. 제로 음료의 뜨거운 인기에 최근 스타벅스 등 유명 프랜차이즈 카페에서도 대체당을 활용한 제로 음료를 출시하고 있다. 일반 음료보다 칼로리가
# >> 황덕현 기후환경전문기자 = 15일 밤까지 내륙 곳곳에서 내리는 소나기가 그치고 나면 금요일인 16일부터 다음주 월요일인 19일까지는 낮 동안 덥겠다. 낮 기온이 최고 33도까지 올라가면서 일부 내륙에서는 폭염 특보가
# >> 박예진 인턴 기자 = 한 여성이 주유소에서 주유건을 주유구에 꽂은 채로 차량을 출발시켰다가 주유건이 튕겨 나가면서 건너편에 있던 남성을 가격하는 사고가 발생했다. 지난 13일 보배드림 공식 사회관계망서비스(SNS)에
# >> 이쯤 되면 전쟁입니다. 내년도 최저임금을 얼마로 할지를 놓고 벌이는 신경전 이야기입니다. 최저임금을 결정하는 최저임금위원회가 벌써 4차례 열렸지만 사용자와 노동자 입장은 평행선을 달리고 있습니다. “치솟는 물가에 맞
# >> 우리나라 대표 고전소설 '춘향전'의 주인공 춘향이를 둘러싸고 소설의 배경인 전북 남원시가 시끌시끌하다. 새로 제작된 '춘향 영정'이 10대가 아닌 40, 50대 중년 여인처럼 보인다는 의견이 나와서다. 논란은 지난달
# >> 코스닥 상장 앞둔 알멕·파로스아이바이오, 공모주 환불 제도인 환매청구권 부여 환불 조건을 내걸고 코스닥 상장 절차를 밟는 기업이 늘고 있다. IPO(기업공개) 시장에 훈풍이 불면서 상장 후 주가가 공모가를 밑돌지는
# >> 2023년 K-팝 산업은 영광을 누리는 동시에 한계도 절감했다. 세계 시장에서 K-팝의 경쟁력을 입증했지만, 불투명한 지배구조와 제작 시스템의 전근대적인 구조가 세상에 드러나 몸살을 앓기도 했다. 화려한 겉모습과 달
# >> 최근 북한에서 식량 부족 문제가 ‘고난의 행군’ 이후 최악일 정도로 심각하다는 비밀 인터뷰 내용이 공개됐다. 14일(현지시간) 영국 BBC는 북한 전문 매체 데일리NK의 도움을 받아 평양과 중국 국경 근처 마을 등에
# >> 부산 돌려차기 사건의 범인 이모(31)씨가 사이코패스 지수가 연쇄살인범 강호순과 같은 수준인 것으로 나타났다. 실제 이씨는 수사와 재판 내내 CCTV 영상으로 직접 확인되는 폭행 부분을 제외한 혐의를 모두 부인하며
# >> 건강 검진 때 고지혈증 판정을 받는 경우가 늘고 있다. 핏속에 지방 성분이 지나치게 많은 상태로, 절대 가볍게 볼 질병이 아니다. 점차 혈관이 좁아져 피가 원활하게 흐르지 못하게 되면 동맥경화, 뇌졸중(뇌경색-뇌출혈
# >> 8살 수컷 반달가슴곰 '오삼이'(KM-53)가 숨졌습니다. 국립공원공단은 14일 반달가슴곰 KM-53이 경북 상주시에서 폐사한 것을 확인했다고 밝혔습니다. 지난 13일, 공단 직원이 오삼이를 포획하기 위해 쏜 마취총
# >> 공군 부사관 이예람 중사가 2021년 5월 부대 내 관사에서 사망했다. 상관에게 성추행을 당하고 81일 간 조직 내에서 고립된 끝에 스스로 목숨을 끊었다. 성추행 사건 직후 피해 사실을 신고했으나 피해자에 대한 보호
# >> 강용석 변호사가 합의금을 타낼 목적으로 허위 고소를 종용했다고 블로거 '도도맘' 김미나씨가 법정에서 진술했다. 서울중앙지법 형사18단독 이준구 판사 심리로 지난 14일 열린 강 변호사의 무고 교사 혐의 공판에서 김씨
# >> 동거남 관용차, 보좌진 사적이용 의혹에 “나는 가정폭력의 피해자” SNS 호소글 현재 정치자금법 관련 경찰도 수사중 불륜 등 의혹에 대해서는 해명 없어 국민의힘 황보승희 의원이 동거 중인 부동산 사업자 A씨가 의원실
# >> 캄보디아에서 숨진 채 발견된 한국인 여성 인터넷방송 진행자(BJ) A 씨의 생전 마지막 모습이 담긴 폐쇄회로(CC)TV 영상이 나왔다. 15일(현지시간) 현지 매체에 따르면 지난 6일 캄보디아 수도 프놈펜 인근 칸달
# >> “아저씨가 사랑해” 편하게 접근한 뒤 ‘그루밍’ 성인도 충격에 눈물…중랑서에 범죄사실 고발 혐의 모두 기소 의견 “진짜 아동이면 당했다” 위장수사 시 미수범 처벌 불명확…“입법 촉구” “아저씨는 너를 너무 사랑해.
# >> '제2 마셜플랜'으로 불리는 우크라이나 재건사업 논의가 본격화하면서 HD현대건설기계가 주목받고 있다. 우크라이나 정부는 러시아 침공으로 발생한 재건사업 규모가 향후 10년간 9000억달러(약 1200조원)에 달할 것
# >> 실거래가 지수 뛰고 구매 여력도 좋아져 금리 불안에 미분양 넘쳐나 급등 미지수 한동안 급락하던 집값이 바닥을 찍고 반등할 것이라는 전망이 나오는 가운데, ‘지속적인 상승은 어렵다’는 신중론도 만만찮다. 문재인정부 시
# >> 마스크가 사라진 올 여름은 더 화려하고 과감하다. 코로나 엔데믹(endemic·풍토병으로 굳어진 감염병) 전환 이후 첫 여름휴가를 앞두고 해외여행 수요가 급증하면서 다채로운 색감의 수영복이 인기를 끌고 있다. 패션에
# >> ● 해임 위협 받는 ‘금융 경찰’ SEC 수장 ● 美 의회에서 벌어진 이더리움 공방 ● 민주당, 크립토 정부 개입 찬성 ● 바이든, 겐슬러 해임 가능성 희박 미국 증권거래위원회(SEC) 위원장인 게리 겐슬러가 지속적
# >> 미국 소프트웨어 기업 오라클이 인공지능(AI) 열풍에 힘입어 호실적을 내며 주가가 5거래일 연속 사상 최고치를 경신했다. 14일(이하 현지시간) 뉴욕증시에서 오라클 주가는 전 거래일 대비 4.8% 오른 122.24달
# >> “우리 사회의 소외된 분들을 대변하는 공복으로서 모든 국민이 당당한 주권자가 될 수 있도록 진정한 여러분의 힘, 곧 국민의 힘 김예지가 되도록 최선을 다하겠습니다. 답변해 주신 국무위원 여러분 감사드리고 경청해 주셔
# >> 북한이 국민포털 네이버를 실시간으로 복제한 피싱사이트를 개설해 국민들을 대상으로 해킹 시도를 벌인 정황이 포착됐습니다. 14일 국가정보원은 네이버(naver.com)를 접속했을 때 'naverportal' 등 비정상
# >> 커피 전문점들의 스마트 오더, 사람 대신 주문을 접수하는 키오스크. 이제 더 이상 우리에게 낯선 풍경이 아니죠. 여러분이 잠든 사이에도 디지털 세상은 바삐 돌아가고 있습니다. 어쩌면 우리의 일상과 가장 가깝게 맞닿아
# >> 경북 청도 운문댐 인근 한 유원지에서 이른바 '알박기 텐트'들이 훼손당하는 사건이 발생했다. 지난 13일 한 온라인 커뮤니티에는 '캠핑장에 나타난 닌자'라는 제목 글이 올라왔다. 해당글은 지난 5일 캠핑 관련 커뮤니
# >> 영주시, 사진 없어 진위 의문 필리핀 현지인 등 목격자들 “분명 악어” 경북 영주의 한 하천에 악어로 추정되는 동물이 목격돼 공무원들이 포획에 나섰다. 영주시는 지난 13일 오후 문수면 무섬마을 인근 하천에서 악어로
# >> "춘향 표현하려는 의도 전혀 실현 못해" 시민단체들, 신구 영정 선호도 조사도 "최초 영정 1313표, 새 영정은 113표" 제작기관 "17세 전후의 18세기 여인상 남원 소재 여고생 7명 모습 참고" 설명 지난달
# >> LG에너지솔루션과 삼성SDI가 유럽에서 처음 개최되는 ‘인터배터리’에서 에너지저장장치(ESS)용 배터리 신기술을 공개했다. 유럽은 미국과 함께 ESS 산업 최대 시장으로, 특히 독일에서는 정부 주도 하에 진행되고 있
# >> 14일 오후 강원 속초시 중앙동 상가건물에서 큰불이 나 2시간여 만에 진화됐다. 소방 당국에 따르면 이번 화재는 오후 10시 34분쯤 20여개 점포가 입주한 2층 상가 건물에서 발생해 2시간 20여분 만인 15일 오
# >> '지디의 타임캡슐'은 기업가치 1조원을 꿈꾸는 '내일의 유니콘 기업'을 만나는 인터뷰 코너입니다. "회사의 2년 뒤를 예상해보고, 2년 뒤 다시 만나 그 때 그 다짐과 약속을 점검해보면 어떨까" 하는 취지에서 기획됐
# >> 10년, 20년이 흐른 뒤에는 2023년이 어떻게 기억될까? 여러 방면에서 우울하고, 화나고, 퇴행하는 소식이 많이 들려오는 요즘이라 2023년의 기억이 썩 좋지 않을 수 있다. 하지만 2023년은 대한민국 역사상
# >> 전일의 '무더기 하한가' 사태에 연루된 것으로 의심받는 온라인 주식투자 커뮤니티 운영자 강모씨가 "시장의 억측"이라며 반발했다. 15일 오전 강씨는 자신이 운영하는 네이버 카페 바른투자연구소에 '당장은 죄송하게도 물
# >> 최근 지역 축제 '먹거리 바가지요금'이 논란인 가운데 수원에서 열린 한 축제에서도 이 같은 문제가 발생했다. 14일, 온라인 커뮤니티에 '주말에 열렸던 수원 축제 후기'라는 제목으로 사진이 첨부된 글이 올라왔다. 해
# >> 정의당이 진중권 광운대 특임교수에게 당원권 2년 정지에해당하는 징계를 내렸다. 정의당 서울시당 당기위원회는 지난 12일 진 교수가 당론과 맞지 않는 말을 해 당의 명예를 실추시켰다는 이유로 징계를 결정했다. 정의당
# >> 생방송 진행 중에 유서를 쓰고 극단적인 선택을 시도했던 레이싱모델 출신 아프리카 BJ 임블리(본명 임지혜)의 현재 상태가 위중한 것으로 전해졌다. 지난 13일 유튜버 세자부활은 자신의 유튜브 채널을 통해 “어떠한 벌
# >> 반려견 건강·복지 위한 놀이터, 반대 여론에 신설 가로막혀 ※반려동물 인구 1500만 시대. 반려동물과 행복한 동행을 위해 관련법 및 제도가 점점 진화하고 있다. ‘멍냥 집사’라면 반드시 알아야 할 ‘반려동물(pet
# >> 일본의 후쿠시마 원전 오염수 방류가 임박한 가운데 정부가 15일 후쿠시마 오염수 관련 일일브리핑을 시작했다. 이날 첫 브리핑에서 정부는 “천일염 등 우리 수산물은 안전하며 일부에서 기준치 이상으로 검출된 것으로 보도
# >> 북한이 개발 중인 대형 군사용 무인기가 포착됐다. 15일 NK뉴스에 따르면 미국 위성사진 업체 ‘플래닛 랩스’가 지난 14일 인공위성을 이용해 촬영한 북한 황해도 방현 공군비행장 활주로 사진엔 날개폭이 약 35m인
# >> 올해 4월까지 정부가 거둬들인 국세수입 실적이 지난해 같은 기간에 비해 약 34조원 줄어든 것으로 집계됐다. 영세사업자를 대상으로 한 세정지원에 따른 이연된 세수와 기업들의 영업이익이 좋지 않은 영향으로 관련 세목의
# >> 국내 통신사가 가입자에게 최적의 요금제를 의무적으로 고지하도록 하는 법안이 잇따라 발의됨에 따라 입법에 속도가 붙을 전망이다. 정부 역시 이와 같은 ‘최적요금제’ 서비스 도입을 추진하고 있어 법제화는 시간 문제라는
# >> 인천 소래포구 어시장 앞에서 상인들이 엎드려 절을 합니다. 뒤에 걸린 현수막에는 '고객신뢰 자정대회'라는 글자가 쓰여 있습니다. 바가지 요금과 상술 등으로 소비자 불만이 끊이지 않자 상인들이 사과에 나선 겁니다. 소
# >> 유명 블로거 '도도맘' 김미나 씨가 법정에서 강용석 변호사가 합의금을 타낼 목적으로 허위 고소를 종용했으며, 실제로 강간이나 강제추행을 당한 사실은 없었다고 진술했다. 15일 복수의 언론보도에 따르면 지난 14일 김
# >> 700년 전 고려 선조들의 간절한 기원을 담아 금물로 옮겨쓴 불경은 세계적으로 이름 높은 미술품이다. 불화와 더불어 고려인들의 독창적인 예술품으로 세계미술사에 아로새겨진 이 사경(寫經) 예술의 걸작 한 점이 돌아왔다
# >> 대통령실이 국민참여토론 게시판이라는 온라인 설문을 근거로 공영방송 TV 수신료 분리징수를 추진한 가운데, 가능성만 제기됐던 중복댓글이 실제 확인됐다. 대통령실이 모은 '국민 여론', 중복 댓글 실제 확인 경향신문 데
# >> 폐암 산재 당사자 정태경 전 조리실무사 매연과 약품에 호흡기 손상 계속돼 진료비·생활비 부담 극심…산재 인정은 필수 "급식실 노동자가 안전해야 아이들도 안전" "다시는 나와 같이 폐암에 걸리는 학교급식 종사자가 나오
# >> 윤석열 대통령의 주요 대선 공약 중 하나인 '청년도약계좌'의 은행권 최고 금리가 6.0%로 확정됐다. 5대 은행(KB국민·신한·하나·우리·NH농협)을 포함한 11개 은행은 지난 14일 은행연합회 소비자 포털에 은행별
# >> 마약 상습 소지하고 투약한 혐의로 1심에서 집행유예를 선고받은 작곡가 돈스파이크(본명 김민수·46)가 2심에서 징역형을 선고받고 법정 구속됐다. 15일 오전 10시 서울고법 형사3부(이창형 이재찬 남기정 부장판사)는
# >> 제1연평해전 승전일 맞아 "北 도발에 단호하게 대응할 것" 윤석열 대통령은 15일 "우리의 압도적인 힘만이 적에게 구걸하는 가짜 평화가 아닌 진짜 평화를 가져다줄 것"이라고 했다. 윤 대통령은 이날 오전 페이스북에서
# >> 이른바 ‘노키즈존’을 둘러싼 논란이 주기적으로 반복된다. 노키즈존은 차별적 공간임이 확실하지만, 탄생 이유에 대한 별도의 분석은 필요하다. 노키즈존은 차별이다 2016년 제주시에서 노키즈존 식당 이용을 거부당한 어린
# >> 15일 부산 울산 경남은 대기 불안정으로 소나기가 내리는 곳이 있겠다. 부산기상청에 따르면 이날 부산 울산 경남에는 강한 돌풍과 함께 천둥, 번개를 동반한 소나기가 내리는 곳이 있겠다. 일부 지역에선 우박이 떨어지는
# >> 부산영화인연대가 부산국제영화제(BIFF) 사태를 초래한 이용관 이사장과 조종국 신임 운영위원장 즉각 사퇴를 촉구했다. 인사 내홍 등이 촉발한 사태를 수습하기는커녕 갈등만 키웠다며 이사장까지 즉각 퇴진을 결단하라고 목
# >> 최근 전국 각지에서 잇따르는 이른바 '먹튀' 사건으로 자영업자들이 골머리를 앓고 있는 가운데, 경기도 부천의 한 자영업자가 피해를 호소했다. 지난 13일 한 온라인 커뮤니티에는 "고깃집 먹튀 사건입니다. 도와주세요"
# >> 핵심요약 소주, 생수병에 담아 판매…누리꾼 "재사용 의심" 일부 지역축제서 터무니없는 가격에 먹거리를 팔아 논란이 불거진 가운데 수원 축제에서 바가지를 썼다는 주장이 제기됐다. 15일 온라인커뮤니티에 따르면 '주말에
# >> 친일 화백 논란에 다시 그린 춘향 영정 놓고 일부 시민단체 반발 남원시 "이제는 불필요한 소모전 중단하고 생산적인 논의 해야" 친일 논란으로 새로 그린 전북 남원시 춘향사당의 춘향 영정을 놓고 일부 시민단체들이 "춘
# >> “장경태 의원, 무릎보호대 하면 양반다리 불가능하다고 법적 대응 운운” “‘가짜뉴스’로 김건희 여사를 괴롭힐 때는 언제고…본인이 당하니 억울한가” “양복 입고 양반다리가 되는지 직접 보여드리겠다…양반다리 잘만 돼”
# >> 제주의 한 치과의사가 치과위생사에게 무면허 의료행위를 지시했다는 고발장이 접수돼 경찰이 수사에 나섰습니다. 서귀포경찰서는 의료법 위반 등 혐의로 치과의사 60대 남성 A씨를 입건해 조사하고 있다고 오늘(15일) 밝혔
# >> 15일 새벽 1시24분께 고성군 죽왕면 삼포리의 한 리조트에서 불이 났다가 출동한 119소방대원에 의해 2시간여만에 꺼졌다. 이 화재로 리조트 내 편의점과 횟집 등 건물 100㎡가 불에 탔다. 또 투숙객 240여명이
# >> 미국 백악관 '성 소수자 인권의 달'(프라이드 먼스) 행사에서 한 트랜스젠더 여성 활동가가 가슴을 노출해 논란이 일고 있다. 13일(현지시간) ABC·폭스뉴스 등에 따르면, 카린 장피에르 백악관 대변인은 이날 브리핑
# >> 경기도가 중증외상환자가 원거리 이송 중 사망하는 사례를 막기 위해 지역외상협력병원을 확대하기로 했습니다. 협력병원은 중증외상환자를 긴급 처치한 뒤 권역외상센터로 이송하는 역할을 하게 됩니다. 보도에 강창구 기자입니다
# >> 조응천 더불어민주당 의원은 조국 전 법무부 장관의 총선 출마설을 놓고 "민주당에 조금이라도 애정이 있다면 출마는 접으시는 게 좋다"고 밝혔습니다. 조 의원은 오늘(15일) CBS 라디오 '전영신의 아침저널'에 출연해
# >>
#
#
#
#                                 방송 모아보기 클릭 시해당 방송사 뉴스를 볼 수 있으며LIVE 표시가 된 경우 생중계로시청 가능합니다.
#
#
#
# >> 피부암 3가지…위험요인과 대처법은?
# >> ‘식인 상어’ 백상아리 사체, 완도 해안가서 발견…휴가철 주의하세요
# >> ‘피떡’ 성질에 따라 ‘OOO’ 예후 다르다?
# >> 영국도 반한, BTS ‘불구리’ 레시피
# >> [사설] “오염수 마실 거냐” “마시겠다”…한국 대정부질문의 수준
# >> [진중권 칼럼] 선거가 세탁기인가
# >> [이상렬의 시시각각] ‘피크 코리아(Peak Korea)’ 위기
# >> [시론] 2050 탄소중립, 정치 아닌 공학으로 풀어야
# >> [세상 바꾸는 M]①86세대 이어 새로운 세력 등장한다
# >> [세상 바꾸는 M]②24년생 갑수, 61년생 영수, 90년생 지훈
# >> [세상 바꾸는 M]③이준석 “산업화·민주화 넘어설 어젠다 부재”
# >> “잘만 팔면 주식으로 6~7억원 번다” 인뱅 1년차도 받는 ‘스톡옵션’[머니뭐니]
# >> “여기서는 공짜였어?” 돈 내고 미리 본 사람만 ‘허탈’
# >> 7억하던 개포 전세 13.5억 됐다…입주장 강남 전세의 반격 [부동산360]
# >> “비건치킨이 왜 거기서 나와”…서울국제도서전서 ‘F&B열풍’ 분 이유 [푸드360]
# >> 야 “태평양 물고기는 30년 마셔”…한덕수 ‘오염수 음용’ 발언 비판
# >> “오염수 마실 수 있다, 없다” 공방만…그새 방류는 다가왔다
# >> 오염수 안전하면 수돗물로? 일본 정부 “피폭 바람직하지 않아”
# >> “오염수 바다, 국내산이 뭔 소용…소금·김 1년치 일단 쟁여”
# >> “칠십 평생 이런 우박은 처음"…망가진 봄배추 안고 망연자실
# >> 돈 벌어 이자내기 바쁜 건설사…올해에만 50곳 폐업신고
# >> ‘빵과 팔찌 기부천사’ 월남전 참전용사 김교환 할아버지 별세…향년 93세
# >> ‘오운완’ 열풍 타고 야외 생활체육교실 구름 인파
# >> [월드리포트] 한국 기업 주재원 7명이 중국에서 억류된 이유
# >> [취재파일] 경찰차 1,780대 전조등 전량 교체 소동
# >> [취재파일] 우리나라에서만 신상 공개 논란이 벌어지는 이유
# >> [씨네멘터리] "인어공주"와 'PC'로 본 디즈니 공주 열전
# >> '비리 온상' 태양광, 설비규모 13% 늘었는데 발전량 4% 줄어
# >> 尹 "태양광 정책 결정라인 조사"
# >> 文정부 운동권 실세 정조준하나
# >> 신재생에너지 태양광에 57% 쏠림 심각
# >> "입·사법 권한 이양 연방제 가까운 자치분권 3.0 시대 구현"
# >> 강원·제주·세종·전북 ' 특별자치 연대 활성화' 머리 맞대
# >> "완전한 지역분권, 기본권 회복·경쟁력 확보 우선돼야"
# >> "도·시군 협력 중요…자치권 강화 시민 자율적 참여 필요"
# >> 앞마당에서도 미국 '소프트 파워'에 밀린 러시아 [세계·사람·생각]
# >> 4,000만명이 우울증, 역대 최고로 우울한 미국 사회 [세계·사람·생각]
# >> 1년에 병원 한 번만 찾아도 평균수명 2년 증가 [세계·사람·생각]
# >> 정부와 금융시스템을 신뢰하는 14억 인도 사람들 [세계·사람·생각]
# >> "아니 왜 거기서 춤을"‥선루프 위가 무도장?
# >> 스타벅스, '역차별' 백인 매니저에 327억 원 배상
# >> "30억 원 주인 없나요?"‥안 나타나는 '로또 1등' 당첨자
# >> 갈비뼈 드러낸 사자‥도대체 왜?
# >> 전현희 망신주려고... 감사원, 내부절차도 무시했나
# >> [오마이포토] "감사권 갖고 장난하면 깡패지 감사원이냐" 민주당의 질문
# >> 전현희 "공정하게 '대통령' 근태 감사 실시해라"
# >> [오마이포토] 1인 시위 피켓 들고 감사원 간 전현희 권익위원장
# >> [굿모닝월드]힘차게 노 젓는 사람들, 중국 용선제 풍경
# >> [굿모닝월드]일본인 레슬러가 세네갈에 자리 잡은 이유는?
# >> [굿모닝월드]가정집 수영장에 출몰한 3m 대형 악어
# >> 조태용 안보실장 "한·중 관계 역행 없어야"…발언 수위 조절?
# >> 윤 대통령, 싱하이밍 대사 직접 언급…"부적절 처신, 국민 불쾌"
# >> "한국 입장에 유감"…중국 외교부 '조치 요구' 사실상 거부
# >> "한상혁 면직, 윤석열 총장 정직 데자뷰..정권 바뀌니 똑같이 따라 해"[여의도초대석]
# >> '위안스카이' 언급 尹에 김종민 "지금이 구한말 조선인가..문제 수습 도움 안 돼"[여의도초대석]
# >> ‘국바세 대표’가 본 민주당 “한동훈 도발에 넘어가 부결..실력 부족 반성해야”[여의도초대석]
# >> 이성만·윤관석 체포안 부결에 "민심과 영구 이별..민주당 국민들이 부결시킬 것"[박영환의 시사1번지]
# >> 군위군 편입 앞두고 바빠진 군위 관광 개발, 대구 시티투어 군위코스 다녀와보니…
# >> 대구시 군위군 시대 준비 마쳤다…내달 1일 공식 출발
# >> '대구시 군위군 시대' 지역 소멸 위기 극복 기회될까
# >> 얼룩말 탈출 그 후, 동물원의 존재 이유를 묻다
# >> 청주동물원에 코끼리가 없는 까닭
# >> ‘푸바오’와 ‘세로’의 집, 동물원의 딜레마 [금요시사회]
# >> [정승조의 아트홀릭] 한국의 피카소 김환기 40년 여정(旅程)
# >> [로컬 인사이드] ‘모든 생명은 본성대로 살 때 가장 행복하다’ 생츄어리 이야기
# >> 여름철 필수품 자외선차단제... 상황과 활동에 맞는 바른 사용법은?
# >> [로컬 인사이드] ‘나쁜 엄마’에 나온 이 농장...“나는 모두의 엄마가 되기로 했다”
# >> "70만원→5년후 5000만원" 연 6% 청년도약계좌…오늘 출시
# >> '연 6%' 청년도약계좌, 기본금리 1%p 올렸더니 은행 이자 3조 늘어
# >> 금융위 "청년도약계좌, 7.68~8.86% 적금 가입과 동일 효과"
# >> 청년도약계좌, 주요 은행서 '최대 6.0%' 받으려면…급여이체 '필수'
# >> [입법권 남용하는 국회] `4류 정치`의 품질낮은 입법남발… 21대 국회 가결률 9.4% 뿐
# >> 전경련 "기업성장 해치는 대기업 차별규제, 61개 법률에 342개"
# >> 민주, 상임위원장 재선 전진배치… 혁신위 문제는 해결 못해
# >> 삼성전자, 'ToF 센서' 개발 재도전...XR 시장 노린다
# >> "애플, 2025년 말 비전프로 보급모델 출시"
# >> "LGD·LG이노텍·SK하이닉스, 애플 비전프로에 부품 공급"
# >> "너무 기대했나" 베일 벗은 대환대출… '빅테크' 네카토, 오류 투성
# >> 대환대출 플랫폼 출범… 유명무실 '보험다모아' 전례 밟나
# >> 12월 대환대출 '2라운드' 시작… 1000조 주담대 잡아라
# >> [박진영의 사회심리학] 낯선 칭찬의 소중함
# >> [박진영의 사회심리학] 마음에도 굳은살이 생긴다
# >> [박진영의 사회심리학] 지나친 완벽주의자는 우울하고 외롭다
# >> [박진영의 사회심리학] 우연적이고 느슨한 관계 '친구'가 필요한 이유
# >> "ETF만으로 투자 가능한 세상"…200兆 시대 닻 올린다
# >> 'ETF보다 저렴한 비용'…신한자산운용, 美 인덱스펀드 출시
# >> ETF, 200兆 닻 올린다…"연금·해외 채권·자산배분 주목"
# >> 30년간 주가 5000% 오른 이 나라…하반기 주목할 ETF는
# >> 닥터헬기 비행-비보잉 ‘합동 퍼포먼스’… 저물녘엔 ‘불멍’ 휴식 [2023 서울헬스쇼]
# >> 폐그물 재활용 내장재 적용 전기차 EV9 선보여 [2023 서울헬스쇼]
# >> 한낮 서울광장서 낮잠… “꿀잠 자는 법 배웠어요” [2023 서울헬스쇼]
# >> 앱으로 암 관리-화면 속 트레이너와 홈트… 비대면 헬스케어 인기
# >> FOMC 기준금리 '동결'…"연내 인하 없다" 선 그은 연준 [이슈분석]
# >> [김대호 박사의 오늘 기업·사람] 궈쉬안·에코프로·LG화학·AMD·엔비디아·메타·TSMC·코오롱·한국타이어·대한항공
# >> [굿모닝 마켓] '매둘기' 된 파월…美 연준, 15개월 만에 기준금리 동결
# >> [어제장 오늘장] 제2의 SG사태?…무더기 하한가에 국내 증시 다시 흔들
# >> 위암, 췌장암, 담도암… 젊어도 '이런 사람’은 위험
# >> 햇빛 쨍쨍한 날 어지럽다면? 빈혈 대신 '약' 의심해야
# >> 우울증은 마음의 감기? '전설적 카피'의 수상한 출처
# >> 김영주 국회부의장 “엑스포 홍보 계기 의원외교 관심 커져… 해외서도 긍정 평가” [세계초대석]
# >> “아직 못다 한 이야기”… 꺾이지 않는 ‘시네마 드림’ [나의 삶 나의 길]
# >> 빛으로 그린 그림 [한강로 사진관]
# >> 낯선 한자어 가득한 정책·법령… 국민 10명 중 3명 “이해 어려워” [우리말 화수분]
# >> "살해·고문 혐의"...캄보디아서 韓 BJ 사망 '커지는 의혹' [Y녹취록]
# >> "한반도 전쟁" 표현까지...위기의 한중관계 '불안' [Y녹취록]
# >> "모욕감 말고, 진짜 이유 말해"...한동훈 발언, 이병헌 대사랑 똑같다고? [Y녹취록]
# >> 中에 이걸 넘기려고..."지금까지와 차원이 다른 유출 시도" [Y녹취록]
# >> 재정준칙 잠자는 사이에… 4월까지 나라적자 45.4조원
# >> 산업부 장관, 신재생에너지 비리 재발방지TF 구성 지시
# >> 토종 OTT·IPTV 위기에 민·관 합심…5000억 수혈한다
# >> 쏘카, 전기차 운영으로 탄소배출권 거래 가능해졌다
# >> 尹 지지율 0.7%p 상승 41.1%…호남 10%p 상승·충청 5.9%P 하락
# >> 국힘 1.7%p 내린 35.9% 민주 0.4%p 내린 37.3%
# >> 'TV 수신료' 영구 폐지…찬성 57.9% vs 반대 27.2%
# >> BIFF 혁신한다더니 집안싸움…공분 쌓이는 영화계
# >> 부산영화인연대, BIFF 이용관 이사장에 공개 질의
# >> ‘BIFF 혁신위’ 논의할 간담회 연기
# >> 중진 정지영 감독 “BIFF 혁신위, 첫발부터 잘못”
# >> [현장] "수산물 섭취 않겠다" 日 오염수 방류에 주부들 불안감↑
# >> 제주해녀협회 "우리가 잡은 전복, 우리도 무서운데 누가 먹겠나"
# >> "두려움 크다" 후쿠시마 오염수 방류 임박…거리로 나선 어민들
# >> "우리 뜻은 변하지 않는다" 후쿠시마 오염수 방류 시운전에 어민 반발
# >> 美, 10회 연속 금리인상 뒤 동결…연내 추가 인상 강력 시사(종합2보)
# >> 美긴축기조 계속될 듯…"연내 추가 금리인상…인하는 내년에"
# >> 한미 금리차 2.25%p까지 벌어지나…환율상승·자금유출 압박↑
# >> 한은 "연준 추가인상 시사에 유의…시장 변동성 확대 가능성"
# >> [아는기자]피의자 신상공개, 어떻게 달라지나?
# >> [다시 간다]쓰레기산 만들고 튄 조폭…“치우려니 수억 원 들어”
# >> [현장 카메라]소리 지르는 방?…7억 헛돈 쓴 강남구청
# >> [아는기자]12년→20년…같은 증거물 두고 다른 판정, 왜?
# >> 약물 회복기…혼자서 끊을 수 있다면 중독이 아닙니다
# >> 한동훈 장관님, 마약과의 전쟁 말고 치료가 필요합니다
# >> 약물에 취해 “엄마를 ‘엄마 탈을 쓴 악당’ 생각”…중독인정 계기는
# >> “평생 약물서 회복하려고 노력해야”…일본 DARC 사람들
# >> 尹 지지율 42.4%…국민 10명 중 6명 "KBS 수신료 분리징수 찬성" [데일리안 여론조사]
# >> 민주당 쇄신책 1위 "이재명 사퇴"…국민 과반 "권칠승 사퇴해야"[데일리안 여론조사]
# >> 30대, 민주당서 '엑소더스' 43.8% → 37.9%…국민의힘에 역전 [데일리안 여론조사]
# >> 민주당 지지자 과반 "中대사 강성발언 'OK'"…국민 65.6% "채용 특혜 선관위 직원 자진 퇴사해야" [데일리안 여론조사]
# >> 잃어버린 마을에서, 4·3에 전하는 특별한  위로
# >> 저금리 따라.. 아파트 "월세 대신, 전세  가볼까?"
# >> 오늘부터 '후쿠시마 오염수 방류' 일일 브리핑..어떤  내용?
# >> '5년 뒤 5,000만 원' 年 6% '청년도약계좌' 오늘 출시.. 가입 어떻게?
# >> [픽&톡]의대 정원 확대 합의했지만 '산 넘어 산'
# >> [줌인]  내 전답 4년 농사 안 지으면 남의 땅?
# >> [뉴스 즉설]국민의힘·민주당 둘다 NO, 내년 총선 MZ세대 손에 달렸다
# >> [뉴스 즉설]흔들어도 꿈쩍 않는 이재명의 민주당, 이대로 총선가나
# >> 40대 女 약사는 왜 GMC 픽업을 구매했을까
# >> 3억 있어도 못 산다...벤틀리, 컨티넨탈 GT 3총사 출시
# >> 볼트 풀리니 되살아난 쉐보레...GM표 전기차 ‘순항’
# >> 치킨값 3000원 올리고 3000원 할인 이벤트 했지만… 방문객 20% 뚝!
# >> 유통업계에 부는 챗GPT 중심 AI 바람
# >> 커지는 ‘中·美 소비 부진’ 우려… 섣부른 경기회복 기대는 금물
# >> “집에 불났는데 고기 파티 한 격” 비상경영 선포하고 6억 주식 성과급 받은 최정우 포스코 회장
# >> Yoon orders probe into officials responsible for allegedly corrupt solar projects
# >> Korean biz leaders join forces for hydrogen leadership
# >> [From the scene] Is investment drought near end for Korean biotech?
# >> 초라했지만 담담히 넘긴 삶… ‘초부의 시’  닮은 길을 밟다[박경일기자의 여행]
# >> 中의 AI 안면인식 기술에 탈북루트도 ‘빨간불’...기차 탑승하다 잡힌 사례도
# >> 미국 대선때마다 사법 리스크… ‘피고인 트럼프’는 레이스 완주할까 [Global Focus]
# >> 中 군 전략가, “우크라 전쟁 예상 못해 충격…매우 우려”
# >> 천하람 “김기현 100일, 챗GPT에 물어보면 충분한 데이터 없다고 할 것”
# >> 김기현 “민주당 중국 돈 받고 나라 팔아···형사처벌 될 수 있다”
# >> 서울 민간아파트 평균 분양가 3.3㎡당 3100만원 넘겼다…5개월 연속 상승
# >> 지난해 노인학대 6800건…“노인부부 가구서 학대 증가”
# >> [약손+] 통증의 공포, '대상포진' ⑭신경치료
# >> [뉴스+] 대구 온 검찰총장 "체포동의안 부결 유감"
# >> [백투더투데이] "이게 호두야, 우박이야" 1978년 경산 우박 피해
# >> [토크와이드] 대구 부동산, '역전세난' 본격화하나?
# >> 금리 올린다는데 안 믿는 시장…한은 "변동성 확대" 우려 [강진규의 외환·금융 워치]
# >> 美 최종금리 0.5%p 상향…한미 금리차 2%p로 벌어지나 [강진규의 외환·금융 워치]
# >> Fed, 15개월 만에 금리인상 멈췄지만…'올해 두번 더 오른다' [Fed 워치]
# >> 금리 동결한 파월 "7월 금리 인상? 결정된 것 없다" - 일문일답 [Fed 워치]
# >> [한화 조선사업 진출⑤]빛발한 김동관의 '오렌지로드'…부산서 '군함명가' 재건 신호탄 쐈다
# >> [한화 조선사업 진출④] 대우조선 45년 만에 역사 뒤안길로… '한화오션' 공식 출범
# >> [한화 조선사업 진출③] 닻 올린 '한화오션', 신임대표에 권혁웅 부회장
# >> [한화 조선사업 진출②]대우조선 새주인 자리 꿰찼다…"공정위 조건부 승인 수용"
# >> [THINK ENGLISH] 또 올라? 계속되는 명품 가격 인상 … 불경기일수록 비싸게 판다
# >> [THINK ENGLISH] 러시아 주재 북한 외교관 아내와 아들 실종
# >> [THINK ENGLISH] 제니하우스에 K-뷰티 체험하러 온 말레이시안 인플루언서들
# >> '갈팡질팡' 환테크족… 갈피 못잡는 환율에 달러예금 들까 말까 [재테크 '대혼돈의 시대']
# >> 美 금리동결 기대감... 환율 1270원대 급락 [재테크 '대혼돈의 시대']
# >> "美금리·지정학 리스크 불확실… '안정성' 위주로 투자하라" [투자 대혼돈의 시대]
# >> 리오프닝 기대감이 실망으로...반등 기대했던  개미들 '울상' [재테크 '대혼돈의 시대']
# >> 테슬라 이겼던 루이비통, 이제 성장세 꺾이나[특이점이 온 명품②]
# >> 변화하는 명품 시장…주목받는 '매스티지'[특이점이 온 명품]
# >> 12살의 샤넬과 71살의 사넬 [EDITOR's LETTER]
# >> 전 부처 ‘인구정책 어벤저스’ 뜬다[인구, 대한민국의 미래다!]
# >> “출퇴근자·관광객까지 고려… ‘생활인구’ 중점 둔 정책이 효과낼 것”[인구, 대한민국의 미래다!]
# >> “저출산 해결, 아빠육아가 답…일·가정 양립 어려움 나눠야”[인구, 대한민국의 미래다!]
# >> ‘가을이 사건’ 친모, 학대 살해 인정… “죽을 죄 지었다” 뒤늦은 반성
# >> [단독] ‘조종국, BIFF 남아야’…이용관 맘대로
# >> [단독] 박민식 “유엔기념공원, 보훈부서 맡아 세계적 성지로 가꾸겠다”
# >> 친일 행적 논란 ‘남인수 가요제’, 장소 바꿔 부활 강행
# >> 멜론 vs 참외, 자주 먹었더니 혈압·혈전에 변화가?
# >> '혈관 튼튼' 피 맑게 하는 여름 제철 식품 5
# >> 과학적으로 증명된 통증 퇴치 식품 9
# >> [주간 뉴스타파] '의정'과 '사익' 사이... 김남국, 조명희, 최영희
# >> [히든머니 프로젝트] “대정부 영업 활동”... 조명희 의원의 내 회사 챙기기
# >> [히든머니 프로젝트] 최영희, 국회법 어기고 일가족 위한 법안 발의
# >> 국회사무처 2023년 재산신고 시, 가상자산 신고기재 요청했었다
# >> 돈키호테 이준석은 도대체 어떤 사람인가 [+영상]
# >> 86세대 선두주자 송영길, 돈봉투에 발목 잡히다 [+영상]
# >> ‘유퀴즈 펀드매니저’ 김현준이 알려준 부자가 주식 고르는 법 [+영상]
# >> 대통령 3인 통역‧尹 의전비서관 김일범, 두 번째 기업行
# >> 쓰지도 않은 카드대금 물어낼 판에…사기공범 피소까지
# >> 최고 90대 1 vs 신청 '0'…청약 양극화 극심
# >> '성범죄자알림e' 미혼 여성엔 미통보…"대상 확대해야"
# >> [2023 데이터센터 서밋 코리아] 차세대 데이터센터(SDDC) 기업·기관·지자체 한 자리···1000명 몰렸다
# >> [2023 데이터센터 서밋 코리아]데이터센터 유치 올인하는 지자체
# >> [2023 데이터센터 서밋 코리아]데이터센터 에너지 효율화와 안정적 운영화
# >> [2023 데이터센터 서밋 코리아]정용석 효성인포 수석컨설턴트 “차세대 데이터센터, 서비스 연속성 확보 중요…노하우·인력 살펴야”
# >> K방산에도 도광양회가 필요하다[한반도 리뷰]
# >> 중국 전랑외교를 대하는 우리의 자세[베이징노트]
# >> [파고들기]버블이 연 최애와의 메시지 서비스, 위버스 DM도 한다
# >> [법정B컷]"그걸 변명이라고"…강서구 전세사기 공범들의 폭탄돌리기
# >> “노출 꺼리는 자립준비청년, 카톡으로 상담하세요”
# >> 자립준비청년 돕는 방법·사례 한눈에 알 수 있도록 정리했다
# >> 또래 친구들이 땀 흘려 선물한 자립준비청년 보금자리
# >> [차담차담] 두 달 월급으로 'My Car'를
# >> [단독] 선관위, 4년전 감사원 채용문제 지적에 '감사 거부' 용역 발주
# >> [단독] 尹 "선관위원장 상근 전임제 해야"…권익위 "대법관 겸직 관례 개선"
# >> [따져보니] 중국인 선거권 논란…"지역 주민" vs "상호주의"
# >> “2억으로 은퇴해도 불안하지 않네”... 60대 남성 자산수명 계산해보니  [왕개미연구소]
# >> ‘5년에 5000만원’ 청년도약계좌 금리 최고 6%로 확정
# >> 전기차 충전 규격도 생산 방식도… 주도하는 테슬라
# >> 역전세 우려에… 서울 소형 아파트 월세가 50% 육박
# >> 곳곳에 버블 경고음 … K- 팝 거품누각 [視리즈]
# >> 여의도엔 정말 '크루즈' 오갈 수 있을까 [추적+]
# >> "3천원요?" 빌라 사는 진씨네 전기요금 1년 전과 비교해보니… [추적+]
# >> 문 닫는 도봉고등학교 가보니… 사라질 공간에 남은 흔적들
# >> [사이언스샷] 토성 위성 엔켈라두스에서 생명체 필수 물질 나왔다
# >> [사이언스샷] “불개미 연구, 로봇개에 맡기세요” 생태 연구에 첨단기술 총동원
# >> [사이언스샷] 태양의 검은 구멍, 샤워기처럼 태양풍 쏟아낸다
# >> [사이언스샷] 북극 온난화 막는 해빙이 무너진다, 소멸 시기 10년 당겨져
# >> [여성논단] 변화한 청년, 그러나 과거에 정체한 저출산 대책
# >> [여성논단] 딸 선호는 성평등이 아니다
# >> [여성논단] 민간 주도의 다양성 증진과 포용적 문화 확산이 필요하다
# >> [여성논단] 페미 대 반페미 구도에 갇힌 '젠더갈등의 정치' 되돌아 볼 때
# >> '취임 100일' 김기현, '능력 중심 민심 공천' 강조 [TF사진관]
# >> 항소심 출석하는 돈스파이크... '징역 2년 실형' [TF사진관]
# >> '불법 대선자금 수수' 김용, 공판 출석 [TF사진관]
# >> '싱하이밍 사태' 속 중국 출국하는 민주당 의원들 "국익 차원" [TF사진관]
# >> 퇴근 후 딱 한 잔?... 소량 음주, '심장질환·암'에 미치는 영향
# >> 곧 다가올 열대야, 폭염대비 필독해야 할 건강수칙은?
# >> 외로움이 암생존자 사망률 높인다
# >> 성기능 감소... 남성호르몬에 안 좋은 7가지 음식
# >> 전세 계약 후엔 OOO 확인해야 [전세사기 예방]③
# >> 19억 횡령 직원 ‘처벌불원’…평생 어부바 신협
# >> ‘정자도 노화’…45세 넘으면 운동성 급감
# >> 싱 대사가 쏘아올린 한중 갈등…돌파구 있나?
# >> '당국 압박 통했다' 청년도약계좌 기본금리 1%p 인상
# >> [청년도약계좌 논란]재주는 은행, 생색은 정부?
# >> [청년도약계좌 논란]금리 공시, 막판까지 뜸들이는 이유
# >> 손님은 하나의 주문에 한 가지 맛을 먹지 않는다[전수경의 MZ 여성 그리고 빈곤]
# >> 강아지유치원 교사 '수난사', 무릎 나가고 혼마저 털렸다[전수경의 MZ 여성 그리고 빈곤]
# >> 힘겹게 꺼낸 "못하겠어요"에 "천천히 해"라는 답이 돌아왔다[전수경의 MZ 여성 그리고 빈곤]
# >> '삼인분 찌개' 거절 못하는 선의를 센터는 날름 받아먹는다[전수경의 MZ 여성 그리고 빈곤]
# >> '인도 주정차' 꼼짝 마.. 다음 달부터 "사진 찍어 신고하면 과태료"
# >> "뒤늦게 땅 파고, 풀 심고"..잼버리대회 코앞인데
# >> "세아베스틸 1,500억 투자"..대표 지키려는 제스처?
# >> "사과 산지 무주에서 과수화상병".. 농민들 이중고
# >> [성상민의 문화 뒤집기] 이어지는 영화제 위기, 어떤 리빌딩이 필요한가
# >> 한상혁 다음은 정연주? 왜 지금 방통심의위 '검사' 나서나
# >> 방통위, TV수신료 분리징수 시행령 개정논의 본격 착수
# >> 한상혁 면직 집행정지 심리 중 '윤석열 검찰총장' 전례 나왔다
# >> 뉴욕증시, FOMC ‘매파적 동결’에 혼조 마감 ‘엔비디아 4.81%↑’…유가·비트코인 하락 [출근전 꼭 글로벌브리핑]
# >> 병 주고 약 준 '매파적 금리 동결'…점도표에 놀란 가슴, 파월이 달랬다 [신인규의 글로벌마켓 A/S]
# >> 파월 "올해 추가 금리인상이 적절…인하는 2~3년 걸릴 것"
# >> 美 스타벅스, 매니저에 327억원 배상한다…왜?
# >> 금리 동결 후 연내 2번 더 올린다는 연준…"지킬 & 하이드냐"
# >> 美 11회 만에 기준금리 동결…향후 인상 가능성은?
# >> 美 금리 인상 멈췄지만 곧 재개?…"긴축 마무리 위한 출구전략"
# >> 연준 금리동결에도 경계심 유지하는 한은 "추가 인상 가능성 유의"
# >> 애널보다 유튜버, 펀드보다 리딩방...불신의 늪, 韓자본시장
# >> 스타 CEO 일탈·유튜버의 애널 ‘저격’…’불나방’ 세상 만든 7大 불신 바이러스
# >> 금융사 불법 행위 걸리면 ‘일벌백계’…애널리스트는 개인 투자자와 더 소통
# >> 유사투자자문 규제법 6월 통과 시급
# >> 인력·예산 태부족… 갈 길 먼 ‘장기요양 재택의료센터’
# >> 경기도~서울 출퇴근길 숨통 트인다
# >> 인천 항만배후단지 제도개선 용역 놓고 ‘시끌’
# >> ‘주차 지옥’ 인천 남동산단, 주차장 확보 난항 [집중취재]
# >> 구독하신 기자가 최근 48시간 이내 작성한 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.
# >> 기자별 기사를 자동 추천해 드립니다. 기자를 구독하시면 해당 기자의 최신 기사를 언론사별에서 확인할 수 있습니다.
# >> 2009년 정리해고에 맞서 장기 파업을 벌인 쌍용자동차 노동자들을 지원한 금속노조가 33억여 원을 배상하는 것은 과도하다는 대법원 판단이 나왔다. 대법원 3부는 쌍용자동차가 금속노조를 상대로 낸 손해배상 청구 소송에서 "금속노조가 회사에 33억1140만 원과 지연손해금을 지급하라"고 판결한 원심을 깨고 15일 사건을 서울고법으로 돌려보냈다. 재판부는 "이 사건 파업이 정당성의 한계를 벗어났으므로 피고(금속노조)는 그로 인한 원고(쌍용차)의 손해를 배상할 책임이 있다고 본 원심의 판단에는 잘못이 없다"고 했다. 하지만 "원고가 2009년 12월경 파업 복귀자들에게 지급한 18억8200만 원은 파업과 상당한 인과관계에 있는 손해라고 보기 어렵다"며 "해당 금액을 배상금 산정에서 제외하라"고 밝혔다. 금속노조 쌍용차지부 조합원들은 2009년 5~8월, 77일 동안 정리해고 반대 파업 농성을 벌였다. 쌍용차는 이로 인해 생산 차질 등 손해가 발생했다며 노조와 소속 조합원들을 상대로 손해배상...
# >> 구독한 연재 중 최근 48시간 이내 작성된 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.
# >> 다양한 연재 기사를 자동 추천해 드립니다. 연재를 구독하시면 해당 연재의 최신 기사를 언론사별에서 확인할 수 있습니다.
# >> 댓글 게시판 운영정책 변경 예고
# >>
# 전체서비스
#
# >>
#
# 이용약관
# 개인정보처리방침
# 청소년 보호 책임자 : 이희만
# 서비스안내
#
# 각 언론사가 직접 콘텐츠를 편집합니다.

# %%
driver = webdriver.Chrome()

driver.get("https://www.naver.com")
time.sleep(3)

search_box = driver.find_element("id", "query")

# %%
search_box.send_keys("zbd")
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 search_box.send_keys("zbd")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:231, in WebElement.send_keys(self, *value)
#     228             remote_files.append(self._upload(file))
#     229         value = "\n".join(remote_files)
# --> 231 self._execute(
#     232     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     233 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#     348     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=114.0.5735.134); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x002AA813+48355]
# 	(No symbol) [0x0023C4B1]
# 	(No symbol) [0x00145358]
# 	(No symbol) [0x0014E5A3]
# 	(No symbol) [0x00148A78]
# 	(No symbol) [0x00147C03]
# 	(No symbol) [0x001499E1]
# 	(No symbol) [0x00149A80]
# 	(No symbol) [0x0017127B]
# 	(No symbol) [0x00171301]
# 	(No symbol) [0x0016BA3F]
# 	(No symbol) [0x0018A73C]
# 	(No symbol) [0x00169A36]
# 	(No symbol) [0x0018AA94]
# 	(No symbol) [0x0019C922]
# 	(No symbol) [0x0018A536]
# 	(No symbol) [0x001682DC]
# 	(No symbol) [0x001693DD]
# 	GetHandleVerifier [0x0050AABD+2539405]
# 	GetHandleVerifier [0x0054A78F+2800735]
# 	GetHandleVerifier [0x0054456C+2775612]
# 	GetHandleVerifier [0x003351E0+616112]
# 	(No symbol) [0x00245F8C]
# 	(No symbol) [0x00242328]
# 	(No symbol) [0x0024240B]
# 	(No symbol) [0x00234FF7]
# 	BaseThreadInitThunk [0x766C6359+25]
# 	RtlGetAppContainerNamedObjectPath [0x77A27A94+228]
# 	RtlGetAppContainerNamedObjectPath [0x77A27A64+180]
# 	(No symbol) [0x00000000]

# %%
import pandas as pd
dirver = webdriver.Chrome()
url = "https://finance.naver.com/item/main.naver?code=005930/"
driver.get(url)
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 dirver = webdriver.Chrome()
#       3 url = "https://finance.naver.com/item/main.naver?code=005930/"
# ----> 4 driver.get(url)
#       5 time.sleep(3)
#
# NameError: name 'driver' is not defined

# %%
html = driver.page_source
talbes = pd.read_html(html)
tables[0]
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 html = driver.page_source
#       2 talbes = pd.read_html(html)
#       3 tables[0]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:447, in WebDriver.page_source(self)
#     438 @property
#     439 def page_source(self) -> str:
#     440     """Gets the source of the current page.
#     441
#     442     :Usage:
#    (...)
#     445             driver.page_source
#     446     """
# --> 447     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#     348     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=114.0.5735.134)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x002AA813+48355]
# 	(No symbol) [0x0023C4B1]
# 	(No symbol) [0x00145358]
# 	(No symbol) [0x0012D293]
# 	(No symbol) [0x0018E37B]
# 	(No symbol) [0x0019C473]
# 	(No symbol) [0x0018A536]
# 	(No symbol) [0x001682DC]
# 	(No symbol) [0x001693DD]
# 	GetHandleVerifier [0x0050AABD+2539405]
# 	GetHandleVerifier [0x0054A78F+2800735]
# 	GetHandleVerifier [0x0054456C+2775612]
# 	GetHandleVerifier [0x003351E0+616112]
# 	(No symbol) [0x00245F8C]
# 	(No symbol) [0x00242328]
# 	(No symbol) [0x0024240B]
# 	(No symbol) [0x00234FF7]
# 	BaseThreadInitThunk [0x766C6359+25]
# 	RtlGetAppContainerNamedObjectPath [0x77A27A94+228]
# 	RtlGetAppContainerNamedObjectPath [0x77A27A64+180]
# 	(No symbol) [0x00000000]
